# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_cities = "output_cities.csv"


#Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 582

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
i=0
wind = []
clouds = []
humidity = []
country = []
date = []
temperture = []
city_found = []
latitude = []
longitude = []

for city in cities:
    i+=1
    print("Record "+str(i))
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
    print(url)
    try:
        weather = requests.get(url).json()
        print("Found "+city)
        wind.append(weather["wind"]["speed"])
        clouds.append(weather["clouds"]["all"])
        humidity.append(weather["main"]["humidity"])
        country.append(weather["sys"]["country"])
        date.append(weather["dt"])
        temperture.append(weather["main"]["temp_max"])
        latitude.append(weather["coord"]["lat"])
        longitude.append(weather["coord"]["lon"])
        city_found.append(city)
    except:
        print("Not found "+city)
# Out:
# Record 1
# http://api.openweathermap.org/data/2.5/weather?q=vao&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vao
# Record 2
# http://api.openweathermap.org/data/2.5/weather?q=amderma&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found amderma
# Not found amderma
# Record 3
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bluff
# Record 4
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found punta arenas
# Record 5
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found los llanos de aridane
# Record 6
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bengkulu
# Record 7
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found busselton
# Record 8
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hermanus
# Record 9
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found anadyr
# Record 10
# http://api.openweathermap.org/data/2.5/weather?q=oussouye&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found oussouye
# Record 11
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found arraial do cabo
# Record 12
# http://api.openweathermap.org/data/2.5/weather?q=ambon&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ambon
# Record 13
# http://api.openweathermap.org/data/2.5/weather?q=alabat&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found alabat
# Record 14
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kodiak
# Record 15
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found thompson
# Record 16
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mahebourg
# Record 17
# http://api.openweathermap.org/data/2.5/weather?q=cordoba&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cordoba
# Record 18
# http://api.openweathermap.org/data/2.5/weather?q=antsohihy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found antsohihy
# Record 19
# http://api.openweathermap.org/data/2.5/weather?q=snina&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found snina
# Record 20
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bethel
# Record 21
# http://api.openweathermap.org/data/2.5/weather?q=ishimbay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ishimbay
# Record 22
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found barrow
# Record 23
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tasiilaq
# Record 24
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tuatapere
# Record 25
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found qaanaaq
# Record 26
# http://api.openweathermap.org/data/2.5/weather?q=samusu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found samusu
# Not found samusu
# Record 27
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found port alfred
# Record 28
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found butaritari
# Record 29
# http://api.openweathermap.org/data/2.5/weather?q=faanui&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found faanui
# Record 30
# http://api.openweathermap.org/data/2.5/weather?q=rungata&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found rungata
# Not found rungata
# Record 31
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found east london
# Record 32
# http://api.openweathermap.org/data/2.5/weather?q=smithers&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found smithers
# Record 33
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mataura
# Record 34
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found attawapiskat
# Not found attawapiskat
# Record 35
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cidreira
# Record 36
# http://api.openweathermap.org/data/2.5/weather?q=rolim de moura&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found rolim de moura
# Not found rolim de moura
# Record 37
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found port elizabeth
# Record 38
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cabo san lucas
# Record 39
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fortuna
# Record 40
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ushuaia
# Record 41
# http://api.openweathermap.org/data/2.5/weather?q=souillac&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found souillac
# Record 42
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mount gambier
# Record 43
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vaini
# Record 44
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found rikitea
# Record 45
# http://api.openweathermap.org/data/2.5/weather?q=hami&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hami
# Record 46
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kaitangata
# Record 47
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bredasdorp
# Record 48
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found khatanga
# Record 49
# http://api.openweathermap.org/data/2.5/weather?q=makakilo city&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found makakilo city
# Record 50
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sentyabrskiy
# Not found sentyabrskiy
# Record 51
# http://api.openweathermap.org/data/2.5/weather?q=kendari&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kendari
# Record 52
# http://api.openweathermap.org/data/2.5/weather?q=paita&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found paita
# Record 53
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found upernavik
# Record 54
# http://api.openweathermap.org/data/2.5/weather?q=rocha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found rocha
# Record 55
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hobart
# Record 56
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found puerto ayora
# Record 57
# http://api.openweathermap.org/data/2.5/weather?q=togur&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found togur
# Record 58
# http://api.openweathermap.org/data/2.5/weather?q=vangaindrano&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vangaindrano
# Record 59
# http://api.openweathermap.org/data/2.5/weather?q=ancud&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ancud
# Record 60
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found chokurdakh
# Record 61
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found srednekolymsk
# Record 62
# http://api.openweathermap.org/data/2.5/weather?q=kedrovyy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kedrovyy
# Record 63
# http://api.openweathermap.org/data/2.5/weather?q=fukue&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fukue
# Record 64
# http://api.openweathermap.org/data/2.5/weather?q=dingle&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dingle
# Record 65
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kapaa
# Record 66
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found albany
# Record 67
# http://api.openweathermap.org/data/2.5/weather?q=lubango&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lubango
# Record 68
# http://api.openweathermap.org/data/2.5/weather?q=tsaratanana&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tsaratanana
# Record 69
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found taolanaro
# Not found taolanaro
# Record 70
# http://api.openweathermap.org/data/2.5/weather?q=sarab&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sarab
# Record 71
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saskylakh
# Record 72
# http://api.openweathermap.org/data/2.5/weather?q=christchurch&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found christchurch
# Record 73
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found guerrero negro
# Record 74
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bubaque
# Record 75
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tiksi
# Record 76
# http://api.openweathermap.org/data/2.5/weather?q=sinkat&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sinkat
# Not found sinkat
# Record 77
# http://api.openweathermap.org/data/2.5/weather?q=winnemucca&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found winnemucca
# Record 78
# http://api.openweathermap.org/data/2.5/weather?q=mogapi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mogapi
# Record 79
# http://api.openweathermap.org/data/2.5/weather?q=muisne&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found muisne
# Record 80
# http://api.openweathermap.org/data/2.5/weather?q=yaan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yaan
# Record 81
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found codrington
# Record 82
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found iqaluit
# Record 83
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bambous virieux
# Record 84
# http://api.openweathermap.org/data/2.5/weather?q=cururupu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cururupu
# Record 85
# http://api.openweathermap.org/data/2.5/weather?q=tezu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tezu
# Record 86
# http://api.openweathermap.org/data/2.5/weather?q=starokozache&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found starokozache
# Record 87
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ugoofaaru
# Record 88
# http://api.openweathermap.org/data/2.5/weather?q=ust-kuyga&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ust-kuyga
# Record 89
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lompoc
# Record 90
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mar del plata
# Record 91
# http://api.openweathermap.org/data/2.5/weather?q=bireun&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bireun
# Record 92
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found avarua
# Record 93
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cape town
# Record 94
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found victoria
# Record 95
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ribeira grande
# Record 96
# http://api.openweathermap.org/data/2.5/weather?q=nome&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nome
# Record 97
# http://api.openweathermap.org/data/2.5/weather?q=vieux-habitants&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vieux-habitants
# Record 98
# http://api.openweathermap.org/data/2.5/weather?q=batsfjord&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found batsfjord
# Record 99
# http://api.openweathermap.org/data/2.5/weather?q=doha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found doha
# Record 100
# http://api.openweathermap.org/data/2.5/weather?q=pevek&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pevek
# Record 101
# http://api.openweathermap.org/data/2.5/weather?q=kristiansund&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kristiansund
# Record 102
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint-philippe
# Record 103
# http://api.openweathermap.org/data/2.5/weather?q=felanitx&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found felanitx
# Record 104
# http://api.openweathermap.org/data/2.5/weather?q=azimur&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found azimur
# Not found azimur
# Record 105
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tessalit
# Record 106
# http://api.openweathermap.org/data/2.5/weather?q=assiniboia&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found assiniboia
# Record 107
# http://api.openweathermap.org/data/2.5/weather?q=weston&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found weston
# Record 108
# http://api.openweathermap.org/data/2.5/weather?q=honiara&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found honiara
# Record 109
# http://api.openweathermap.org/data/2.5/weather?q=isangel&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found isangel
# Record 110
# http://api.openweathermap.org/data/2.5/weather?q=basco&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found basco
# Record 111
# http://api.openweathermap.org/data/2.5/weather?q=goderich&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found goderich
# Record 112
# http://api.openweathermap.org/data/2.5/weather?q=flinders&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found flinders
# Record 113
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found new norfolk
# Record 114
# http://api.openweathermap.org/data/2.5/weather?q=margate&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found margate
# Record 115
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nanortalik
# Record 116
# http://api.openweathermap.org/data/2.5/weather?q=miguel hidalgo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found miguel hidalgo
# Record 117
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found jamestown
# Record 118
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cherskiy
# Record 119
# http://api.openweathermap.org/data/2.5/weather?q=leshan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found leshan
# Record 120
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tuktoyaktuk
# Record 121
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found georgetown
# Record 122
# http://api.openweathermap.org/data/2.5/weather?q=sisimiut&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sisimiut
# Record 123
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yellowknife
# Record 124
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found taoudenni
# Record 125
# http://api.openweathermap.org/data/2.5/weather?q=pisco&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pisco
# Record 126
# http://api.openweathermap.org/data/2.5/weather?q=bahua&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bahua
# Record 127
# http://api.openweathermap.org/data/2.5/weather?q=llanes&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found llanes
# Record 128
# http://api.openweathermap.org/data/2.5/weather?q=teya&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found teya
# Record 129
# http://api.openweathermap.org/data/2.5/weather?q=along&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found along
# Record 130
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found belushya guba
# Not found belushya guba
# Record 131
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found atuona
# Record 132
# http://api.openweathermap.org/data/2.5/weather?q=panguna&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found panguna
# Record 133
# http://api.openweathermap.org/data/2.5/weather?q=tunduru&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tunduru
# Not found tunduru
# Record 134
# http://api.openweathermap.org/data/2.5/weather?q=ingham&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ingham
# Record 135
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found longyearbyen
# Record 136
# http://api.openweathermap.org/data/2.5/weather?q=moerai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found moerai
# Record 137
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found geraldton
# Record 138
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found castro
# Record 139
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saldanha
# Record 140
# http://api.openweathermap.org/data/2.5/weather?q=sorland&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sorland
# Record 141
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found chuy
# Record 142
# http://api.openweathermap.org/data/2.5/weather?q=valparaiso&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found valparaiso
# Record 143
# http://api.openweathermap.org/data/2.5/weather?q=nuqui&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nuqui
# Record 144
# http://api.openweathermap.org/data/2.5/weather?q=karamea&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found karamea
# Not found karamea
# Record 145
# http://api.openweathermap.org/data/2.5/weather?q=xam nua&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found xam nua
# Record 146
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found belmonte
# Record 147
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found constitucion
# Record 148
# http://api.openweathermap.org/data/2.5/weather?q=tuggurt&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tuggurt
# Not found tuggurt
# Record 149
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found egvekinot
# Record 150
# http://api.openweathermap.org/data/2.5/weather?q=contai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found contai
# Record 151
# http://api.openweathermap.org/data/2.5/weather?q=port blair&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found port blair
# Record 152
# http://api.openweathermap.org/data/2.5/weather?q=pinawa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pinawa
# Record 153
# http://api.openweathermap.org/data/2.5/weather?q=batesville&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found batesville
# Record 154
# http://api.openweathermap.org/data/2.5/weather?q=the valley&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found the valley
# Record 155
# http://api.openweathermap.org/data/2.5/weather?q=sitka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sitka
# Record 156
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hilo
# Record 157
# http://api.openweathermap.org/data/2.5/weather?q=berlevag&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found berlevag
# Record 158
# http://api.openweathermap.org/data/2.5/weather?q=kaa-khem&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kaa-khem
# Record 159
# http://api.openweathermap.org/data/2.5/weather?q=cloquet&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cloquet
# Record 160
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tsihombe
# Not found tsihombe
# Record 161
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hofn
# Record 162
# http://api.openweathermap.org/data/2.5/weather?q=padang&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found padang
# Record 163
# http://api.openweathermap.org/data/2.5/weather?q=marzuq&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found marzuq
# Record 164
# http://api.openweathermap.org/data/2.5/weather?q=yarada&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yarada
# Record 165
# http://api.openweathermap.org/data/2.5/weather?q=mogok&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mogok
# Record 166
# http://api.openweathermap.org/data/2.5/weather?q=bridlington&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bridlington
# Record 167
# http://api.openweathermap.org/data/2.5/weather?q=innisfail&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found innisfail
# Record 168
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ust-nera
# Record 169
# http://api.openweathermap.org/data/2.5/weather?q=bezhetsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bezhetsk
# Record 170
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ponta do sol
# Record 171
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found grand gaube
# Record 172
# http://api.openweathermap.org/data/2.5/weather?q=zverinogolovskoye&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zverinogolovskoye
# Record 173
# http://api.openweathermap.org/data/2.5/weather?q=iquique&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found iquique
# Record 174
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vaitupu
# Not found vaitupu
# Record 175
# http://api.openweathermap.org/data/2.5/weather?q=kurilsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kurilsk
# Record 176
# http://api.openweathermap.org/data/2.5/weather?q=changli&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found changli
# Record 177
# http://api.openweathermap.org/data/2.5/weather?q=airai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found airai
# Record 178
# http://api.openweathermap.org/data/2.5/weather?q=liwale&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found liwale
# Record 179
# http://api.openweathermap.org/data/2.5/weather?q=san patricio&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found san patricio
# Record 180
# http://api.openweathermap.org/data/2.5/weather?q=brawley&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found brawley
# Record 181
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hithadhoo
# Record 182
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found aklavik
# Record 183
# http://api.openweathermap.org/data/2.5/weather?q=husavik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found husavik
# Record 184
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found illoqqortoormiut
# Not found illoqqortoormiut
# Record 185
# http://api.openweathermap.org/data/2.5/weather?q=hue&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hue
# Record 186
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found barentsburg
# Not found barentsburg
# Record 187
# http://api.openweathermap.org/data/2.5/weather?q=kegayli&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kegayli
# Not found kegayli
# Record 188
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nikolskoye
# Record 189
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found komsomolskiy
# Record 190
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found roald
# Record 191
# http://api.openweathermap.org/data/2.5/weather?q=karratha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found karratha
# Record 192
# http://api.openweathermap.org/data/2.5/weather?q=tottori&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tottori
# Record 193
# http://api.openweathermap.org/data/2.5/weather?q=sakakah&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sakakah
# Record 194
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tazovskiy
# Record 195
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sibolga
# Record 196
# http://api.openweathermap.org/data/2.5/weather?q=creel&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found creel
# Record 197
# http://api.openweathermap.org/data/2.5/weather?q=jega&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found jega
# Record 198
# http://api.openweathermap.org/data/2.5/weather?q=puerto del rosario&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found puerto del rosario
# Record 199
# http://api.openweathermap.org/data/2.5/weather?q=asyut&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found asyut
# Record 200
# http://api.openweathermap.org/data/2.5/weather?q=alofi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found alofi
# Record 201
# http://api.openweathermap.org/data/2.5/weather?q=kungurtug&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kungurtug
# Record 202
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lorengau
# Record 203
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found klaksvik
# Record 204
# http://api.openweathermap.org/data/2.5/weather?q=bonthe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bonthe
# Record 205
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dikson
# Record 206
# http://api.openweathermap.org/data/2.5/weather?q=lebanon&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lebanon
# Record 207
# http://api.openweathermap.org/data/2.5/weather?q=kysyl-syr&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kysyl-syr
# Record 208
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found torbay
# Record 209
# http://api.openweathermap.org/data/2.5/weather?q=esperance&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found esperance
# Record 210
# http://api.openweathermap.org/data/2.5/weather?q=high rock&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found high rock
# Record 211
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ahipara
# Record 212
# http://api.openweathermap.org/data/2.5/weather?q=luwuk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found luwuk
# Record 213
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kruisfontein
# Record 214
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lebu
# Record 215
# http://api.openweathermap.org/data/2.5/weather?q=cubuk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cubuk
# Record 216
# http://api.openweathermap.org/data/2.5/weather?q=nayoro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nayoro
# Record 217
# http://api.openweathermap.org/data/2.5/weather?q=marawi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found marawi
# Record 218
# http://api.openweathermap.org/data/2.5/weather?q=ternovka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ternovka
# Record 219
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found talnakh
# Record 220
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nizhneyansk
# Not found nizhneyansk
# Record 221
# http://api.openweathermap.org/data/2.5/weather?q=andenes&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found andenes
# Record 222
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found meulaboh
# Record 223
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found severo-kurilsk
# Record 224
# http://api.openweathermap.org/data/2.5/weather?q=fonte boa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fonte boa
# Record 225
# http://api.openweathermap.org/data/2.5/weather?q=watertown&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found watertown
# Record 226
# http://api.openweathermap.org/data/2.5/weather?q=portland&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found portland
# Record 227
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mys shmidta
# Not found mys shmidta
# Record 228
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found katsuura
# Record 229
# http://api.openweathermap.org/data/2.5/weather?q=barcelona&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found barcelona
# Record 230
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found palabuhanratu
# Not found palabuhanratu
# Record 231
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found oktyabrskiy
# Record 232
# http://api.openweathermap.org/data/2.5/weather?q=vitim&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vitim
# Record 233
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found grand river south east
# Not found grand river south east
# Record 234
# http://api.openweathermap.org/data/2.5/weather?q=aksarka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found aksarka
# Record 235
# http://api.openweathermap.org/data/2.5/weather?q=atar&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found atar
# Record 236
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yerbogachen
# Record 237
# http://api.openweathermap.org/data/2.5/weather?q=debre birhan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found debre birhan
# Record 238
# http://api.openweathermap.org/data/2.5/weather?q=khonuu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found khonuu
# Not found khonuu
# Record 239
# http://api.openweathermap.org/data/2.5/weather?q=lata&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lata
# Record 240
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sept-iles
# Record 241
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found buraydah
# Record 242
# http://api.openweathermap.org/data/2.5/weather?q=young&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found young
# Record 243
# http://api.openweathermap.org/data/2.5/weather?q=zhuhai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zhuhai
# Record 244
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found caravelas
# Record 245
# http://api.openweathermap.org/data/2.5/weather?q=gamba&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found gamba
# Record 246
# http://api.openweathermap.org/data/2.5/weather?q=lake havasu city&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lake havasu city
# Record 247
# http://api.openweathermap.org/data/2.5/weather?q=usvyaty&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found usvyaty
# Record 248
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found narsaq
# Record 249
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found clyde river
# Record 250
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vestmannaeyjar
# Record 251
# http://api.openweathermap.org/data/2.5/weather?q=marcona&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found marcona
# Not found marcona
# Record 252
# http://api.openweathermap.org/data/2.5/weather?q=zyryanka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zyryanka
# Record 253
# http://api.openweathermap.org/data/2.5/weather?q=puerto el triunfo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found puerto el triunfo
# Record 254
# http://api.openweathermap.org/data/2.5/weather?q=vostok&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vostok
# Record 255
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint-pierre
# Record 256
# http://api.openweathermap.org/data/2.5/weather?q=itarema&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found itarema
# Record 257
# http://api.openweathermap.org/data/2.5/weather?q=yagodnoye&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yagodnoye
# Record 258
# http://api.openweathermap.org/data/2.5/weather?q=prudentopolis&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found prudentopolis
# Record 259
# http://api.openweathermap.org/data/2.5/weather?q=solnechnyy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found solnechnyy
# Record 260
# http://api.openweathermap.org/data/2.5/weather?q=nouakchott&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nouakchott
# Record 261
# http://api.openweathermap.org/data/2.5/weather?q=dawlatabad&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dawlatabad
# Record 262
# http://api.openweathermap.org/data/2.5/weather?q=santa fe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found santa fe
# Record 263
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ketchikan
# Record 264
# http://api.openweathermap.org/data/2.5/weather?q=san rafael&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found san rafael
# Record 265
# http://api.openweathermap.org/data/2.5/weather?q=avera&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found avera
# Record 266
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sao filipe
# Record 267
# http://api.openweathermap.org/data/2.5/weather?q=dawei&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dawei
# Record 268
# http://api.openweathermap.org/data/2.5/weather?q=sambava&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sambava
# Record 269
# http://api.openweathermap.org/data/2.5/weather?q=lethem&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lethem
# Record 270
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saleaula
# Not found saleaula
# Record 271
# http://api.openweathermap.org/data/2.5/weather?q=arenapolis&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found arenapolis
# Record 272
# http://api.openweathermap.org/data/2.5/weather?q=snezhnogorsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found snezhnogorsk
# Record 273
# http://api.openweathermap.org/data/2.5/weather?q=zhifang&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zhifang
# Record 274
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kavieng
# Record 275
# http://api.openweathermap.org/data/2.5/weather?q=baruun-urt&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found baruun-urt
# Record 276
# http://api.openweathermap.org/data/2.5/weather?q=atmakur&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found atmakur
# Record 277
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tumannyy
# Not found tumannyy
# Record 278
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pangnirtung
# Record 279
# http://api.openweathermap.org/data/2.5/weather?q=tutoia&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tutoia
# Record 280
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found leningradskiy
# Record 281
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ostrovnoy
# Record 282
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lavrentiya
# Record 283
# http://api.openweathermap.org/data/2.5/weather?q=puebloviejo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found puebloviejo
# Record 284
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found prince rupert
# Record 285
# http://api.openweathermap.org/data/2.5/weather?q=bandar-e torkaman&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bandar-e torkaman
# Not found bandar-e torkaman
# Record 286
# http://api.openweathermap.org/data/2.5/weather?q=namibe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found namibe
# Record 287
# http://api.openweathermap.org/data/2.5/weather?q=atikokan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found atikokan
# Record 288
# http://api.openweathermap.org/data/2.5/weather?q=olinda&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found olinda
# Record 289
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found beringovskiy
# Record 290
# http://api.openweathermap.org/data/2.5/weather?q=abbeville&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found abbeville
# Record 291
# http://api.openweathermap.org/data/2.5/weather?q=toora-khem&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found toora-khem
# Record 292
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found udachnyy
# Record 293
# http://api.openweathermap.org/data/2.5/weather?q=saint george&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint george
# Record 294
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found belaya gora
# Record 295
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found olafsvik
# Record 296
# http://api.openweathermap.org/data/2.5/weather?q=price&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found price
# Record 297
# http://api.openweathermap.org/data/2.5/weather?q=warqla&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found warqla
# Not found warqla
# Record 298
# http://api.openweathermap.org/data/2.5/weather?q=bilma&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bilma
# Record 299
# http://api.openweathermap.org/data/2.5/weather?q=nemuro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nemuro
# Record 300
# http://api.openweathermap.org/data/2.5/weather?q=novo aripuana&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found novo aripuana
# Record 301
# http://api.openweathermap.org/data/2.5/weather?q=nambucca heads&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nambucca heads
# Record 302
# http://api.openweathermap.org/data/2.5/weather?q=jales&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found jales
# Record 303
# http://api.openweathermap.org/data/2.5/weather?q=ongandjera&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ongandjera
# Record 304
# http://api.openweathermap.org/data/2.5/weather?q=zabaykalsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zabaykalsk
# Record 305
# http://api.openweathermap.org/data/2.5/weather?q=karakendzha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found karakendzha
# Not found karakendzha
# Record 306
# http://api.openweathermap.org/data/2.5/weather?q=sorvag&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sorvag
# Not found sorvag
# Record 307
# http://api.openweathermap.org/data/2.5/weather?q=takahata&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found takahata
# Record 308
# http://api.openweathermap.org/data/2.5/weather?q=langarud&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found langarud
# Record 309
# http://api.openweathermap.org/data/2.5/weather?q=carutapera&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found carutapera
# Record 310
# http://api.openweathermap.org/data/2.5/weather?q=temaraia&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found temaraia
# Not found temaraia
# Record 311
# http://api.openweathermap.org/data/2.5/weather?q=muroto&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found muroto
# Record 312
# http://api.openweathermap.org/data/2.5/weather?q=katherine&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found katherine
# Record 313
# http://api.openweathermap.org/data/2.5/weather?q=skagastrond&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found skagastrond
# Not found skagastrond
# Record 314
# http://api.openweathermap.org/data/2.5/weather?q=novosergiyevka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found novosergiyevka
# Record 315
# http://api.openweathermap.org/data/2.5/weather?q=umm lajj&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found umm lajj
# Record 316
# http://api.openweathermap.org/data/2.5/weather?q=epinal&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found epinal
# Record 317
# http://api.openweathermap.org/data/2.5/weather?q=douentza&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found douentza
# Record 318
# http://api.openweathermap.org/data/2.5/weather?q=yatou&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yatou
# Record 319
# http://api.openweathermap.org/data/2.5/weather?q=mishkino&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mishkino
# Record 320
# http://api.openweathermap.org/data/2.5/weather?q=kadaya&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kadaya
# Record 321
# http://api.openweathermap.org/data/2.5/weather?q=salalah&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found salalah
# Record 322
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fort nelson
# Record 323
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint-augustin
# Record 324
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found oranjemund
# Record 325
# http://api.openweathermap.org/data/2.5/weather?q=timmins&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found timmins
# Record 326
# http://api.openweathermap.org/data/2.5/weather?q=touros&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found touros
# Record 327
# http://api.openweathermap.org/data/2.5/weather?q=solntsevo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found solntsevo
# Record 328
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nouadhibou
# Record 329
# http://api.openweathermap.org/data/2.5/weather?q=bay roberts&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bay roberts
# Record 330
# http://api.openweathermap.org/data/2.5/weather?q=hopkinton&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hopkinton
# Record 331
# http://api.openweathermap.org/data/2.5/weather?q=shancheng&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found shancheng
# Record 332
# http://api.openweathermap.org/data/2.5/weather?q=lulea&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lulea
# Record 333
# http://api.openweathermap.org/data/2.5/weather?q=manokwari&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found manokwari
# Record 334
# http://api.openweathermap.org/data/2.5/weather?q=liaoyang&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found liaoyang
# Record 335
# http://api.openweathermap.org/data/2.5/weather?q=solovetskiy&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found solovetskiy
# Not found solovetskiy
# Record 336
# http://api.openweathermap.org/data/2.5/weather?q=solton&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found solton
# Record 337
# http://api.openweathermap.org/data/2.5/weather?q=zurrieq&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zurrieq
# Record 338
# http://api.openweathermap.org/data/2.5/weather?q=maturin&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found maturin
# Record 339
# http://api.openweathermap.org/data/2.5/weather?q=dublyany&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dublyany
# Record 340
# http://api.openweathermap.org/data/2.5/weather?q=benguela&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found benguela
# Record 341
# http://api.openweathermap.org/data/2.5/weather?q=verkhoyansk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found verkhoyansk
# Record 342
# ...
# Found hay river
# Record 469
# http://api.openweathermap.org/data/2.5/weather?q=kolindros&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kolindros
# Record 470
# http://api.openweathermap.org/data/2.5/weather?q=mahanje&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mahanje
# Record 471
# http://api.openweathermap.org/data/2.5/weather?q=la palma del condado&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found la palma del condado
# Record 472
# http://api.openweathermap.org/data/2.5/weather?q=atambua&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found atambua
# Record 473
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lagoa
# Record 474
# http://api.openweathermap.org/data/2.5/weather?q=neiafu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found neiafu
# Record 475
# http://api.openweathermap.org/data/2.5/weather?q=novopokrovka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found novopokrovka
# Record 476
# http://api.openweathermap.org/data/2.5/weather?q=rio grande&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found rio grande
# Record 477
# http://api.openweathermap.org/data/2.5/weather?q=zhenlai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zhenlai
# Record 478
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bathsheba
# Record 479
# http://api.openweathermap.org/data/2.5/weather?q=coos bay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found coos bay
# Record 480
# http://api.openweathermap.org/data/2.5/weather?q=moultrie&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found moultrie
# Record 481
# http://api.openweathermap.org/data/2.5/weather?q=humaita&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found humaita
# Record 482
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found port lincoln
# Record 483
# http://api.openweathermap.org/data/2.5/weather?q=kaitong&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kaitong
# Record 484
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kloulklubed
# Record 485
# http://api.openweathermap.org/data/2.5/weather?q=miri&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found miri
# Record 486
# http://api.openweathermap.org/data/2.5/weather?q=talas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found talas
# Record 487
# http://api.openweathermap.org/data/2.5/weather?q=vung tau&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vung tau
# Record 488
# http://api.openweathermap.org/data/2.5/weather?q=ferrol&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ferrol
# Record 489
# http://api.openweathermap.org/data/2.5/weather?q=victoria point&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found victoria point
# Record 490
# http://api.openweathermap.org/data/2.5/weather?q=grand-santi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found grand-santi
# Record 491
# http://api.openweathermap.org/data/2.5/weather?q=kirakira&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kirakira
# Record 492
# http://api.openweathermap.org/data/2.5/weather?q=balloszog&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found balloszog
# Record 493
# http://api.openweathermap.org/data/2.5/weather?q=kamloops&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kamloops
# Record 494
# http://api.openweathermap.org/data/2.5/weather?q=dicabisagan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dicabisagan
# Record 495
# http://api.openweathermap.org/data/2.5/weather?q=kolosovka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kolosovka
# Record 496
# http://api.openweathermap.org/data/2.5/weather?q=fevralsk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fevralsk
# Not found fevralsk
# Record 497
# http://api.openweathermap.org/data/2.5/weather?q=cerrito&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found cerrito
# Record 498
# http://api.openweathermap.org/data/2.5/weather?q=samarai&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found samarai
# Record 499
# http://api.openweathermap.org/data/2.5/weather?q=teahupoo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found teahupoo
# Record 500
# http://api.openweathermap.org/data/2.5/weather?q=urumqi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found urumqi
# Record 501
# http://api.openweathermap.org/data/2.5/weather?q=sidmouth&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sidmouth
# Record 502
# http://api.openweathermap.org/data/2.5/weather?q=kyabe&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kyabe
# Record 503
# http://api.openweathermap.org/data/2.5/weather?q=praya&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found praya
# Record 504
# http://api.openweathermap.org/data/2.5/weather?q=bonavista&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bonavista
# Record 505
# http://api.openweathermap.org/data/2.5/weather?q=xinyu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found xinyu
# Record 506
# http://api.openweathermap.org/data/2.5/weather?q=killybegs&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found killybegs
# Record 507
# http://api.openweathermap.org/data/2.5/weather?q=eureka&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found eureka
# Record 508
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lakes entrance
# Record 509
# http://api.openweathermap.org/data/2.5/weather?q=parkes&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found parkes
# Record 510
# http://api.openweathermap.org/data/2.5/weather?q=fort saint john&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found fort saint john
# Not found fort saint john
# Record 511
# http://api.openweathermap.org/data/2.5/weather?q=saryshagan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saryshagan
# Not found saryshagan
# Record 512
# http://api.openweathermap.org/data/2.5/weather?q=saint-georges&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint-georges
# Record 513
# http://api.openweathermap.org/data/2.5/weather?q=naryan-mar&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found naryan-mar
# Record 514
# http://api.openweathermap.org/data/2.5/weather?q=mayo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found mayo
# Record 515
# http://api.openweathermap.org/data/2.5/weather?q=coremas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found coremas
# Record 516
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found carnarvon
# Record 517
# http://api.openweathermap.org/data/2.5/weather?q=sao felix do xingu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sao felix do xingu
# Record 518
# http://api.openweathermap.org/data/2.5/weather?q=jeremie&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found jeremie
# Record 519
# http://api.openweathermap.org/data/2.5/weather?q=pacific grove&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pacific grove
# Record 520
# http://api.openweathermap.org/data/2.5/weather?q=beian&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found beian
# Record 521
# http://api.openweathermap.org/data/2.5/weather?q=svatove&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found svatove
# Record 522
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found sao joao da barra
# Record 523
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kavaratti
# Record 524
# http://api.openweathermap.org/data/2.5/weather?q=durango&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found durango
# Record 525
# http://api.openweathermap.org/data/2.5/weather?q=chichibu&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found chichibu
# Record 526
# http://api.openweathermap.org/data/2.5/weather?q=beaverlodge&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found beaverlodge
# Record 527
# http://api.openweathermap.org/data/2.5/weather?q=acajutla&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found acajutla
# Record 528
# http://api.openweathermap.org/data/2.5/weather?q=vilhena&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found vilhena
# Record 529
# http://api.openweathermap.org/data/2.5/weather?q=gorno-altaysk&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found gorno-altaysk
# Record 530
# http://api.openweathermap.org/data/2.5/weather?q=juneau&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found juneau
# Record 531
# http://api.openweathermap.org/data/2.5/weather?q=alugan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found alugan
# Record 532
# http://api.openweathermap.org/data/2.5/weather?q=ulladulla&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ulladulla
# Record 533
# http://api.openweathermap.org/data/2.5/weather?q=kostomuksha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kostomuksha
# Record 534
# http://api.openweathermap.org/data/2.5/weather?q=luangwa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found luangwa
# Record 535
# http://api.openweathermap.org/data/2.5/weather?q=dongsheng&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found dongsheng
# Record 536
# http://api.openweathermap.org/data/2.5/weather?q=nago&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nago
# Record 537
# http://api.openweathermap.org/data/2.5/weather?q=tura&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found tura
# Record 538
# http://api.openweathermap.org/data/2.5/weather?q=ternate&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ternate
# Record 539
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hasaki
# Record 540
# http://api.openweathermap.org/data/2.5/weather?q=la esperanza&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found la esperanza
# Record 541
# http://api.openweathermap.org/data/2.5/weather?q=lufilufi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lufilufi
# Record 542
# http://api.openweathermap.org/data/2.5/weather?q=magpet&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found magpet
# Record 543
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found lazaro cardenas
# Record 544
# http://api.openweathermap.org/data/2.5/weather?q=nicoya&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found nicoya
# Record 545
# http://api.openweathermap.org/data/2.5/weather?q=massakory&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found massakory
# Record 546
# http://api.openweathermap.org/data/2.5/weather?q=hihifo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hihifo
# Not found hihifo
# Record 547
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found saint-francois
# Record 548
# http://api.openweathermap.org/data/2.5/weather?q=kieta&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kieta
# Record 549
# http://api.openweathermap.org/data/2.5/weather?q=whyalla&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found whyalla
# Record 550
# http://api.openweathermap.org/data/2.5/weather?q=khandbari&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found khandbari
# Record 551
# http://api.openweathermap.org/data/2.5/weather?q=pafos&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found pafos
# Record 552
# http://api.openweathermap.org/data/2.5/weather?q=havelock&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found havelock
# Record 553
# http://api.openweathermap.org/data/2.5/weather?q=zavyalovo&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found zavyalovo
# Record 554
# http://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hambantota
# Record 555
# http://api.openweathermap.org/data/2.5/weather?q=neral&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found neral
# Record 556
# http://api.openweathermap.org/data/2.5/weather?q=ahmadpur&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ahmadpur
# Record 557
# http://api.openweathermap.org/data/2.5/weather?q=flin flon&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found flin flon
# Record 558
# http://api.openweathermap.org/data/2.5/weather?q=malakal&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found malakal
# Record 559
# http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found praia da vitoria
# Record 560
# http://api.openweathermap.org/data/2.5/weather?q=kozhva&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found kozhva
# Record 561
# http://api.openweathermap.org/data/2.5/weather?q=jumla&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found jumla
# Record 562
# http://api.openweathermap.org/data/2.5/weather?q=uvinza&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found uvinza
# Record 563
# http://api.openweathermap.org/data/2.5/weather?q=san onofre&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found san onofre
# Record 564
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found richards bay
# Record 565
# http://api.openweathermap.org/data/2.5/weather?q=yirol&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found yirol
# Not found yirol
# Record 566
# http://api.openweathermap.org/data/2.5/weather?q=volchikha&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found volchikha
# Record 567
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found krasnoselkup
# Record 568
# http://api.openweathermap.org/data/2.5/weather?q=great falls&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found great falls
# Record 569
# http://api.openweathermap.org/data/2.5/weather?q=bambanglipuro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found bambanglipuro
# Record 570
# http://api.openweathermap.org/data/2.5/weather?q=balykshi&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found balykshi
# Record 571
# http://api.openweathermap.org/data/2.5/weather?q=clarence town&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found clarence town
# Record 572
# http://api.openweathermap.org/data/2.5/weather?q=londa&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found londa
# Record 573
# http://api.openweathermap.org/data/2.5/weather?q=orotukan&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found orotukan
# Record 574
# http://api.openweathermap.org/data/2.5/weather?q=la union&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found la union
# Record 575
# http://api.openweathermap.org/data/2.5/weather?q=ostersund&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found ostersund
# Record 576
# http://api.openweathermap.org/data/2.5/weather?q=road town&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found road town
# Record 577
# http://api.openweathermap.org/data/2.5/weather?q=greensboro&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found greensboro
# Record 578
# http://api.openweathermap.org/data/2.5/weather?q=haimen&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found haimen
# Record 579
# http://api.openweathermap.org/data/2.5/weather?q=maryborough&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found maryborough
# Record 580
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found half moon bay
# Record 581
# http://api.openweathermap.org/data/2.5/weather?q=hualmay&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found hualmay
# Record 582
# http://api.openweathermap.org/data/2.5/weather?q=skopin&appid=1d9b9d1d9c8ebacd2388b0c158c18014&units=imperial
# Found skopin

# %%
Weather_df = pd.DataFrame({"Wind":wind,
                          "Clouds":clouds,
                          "Humidity":humidity,
                          "Country":country,
                          "Data":date,
                          "Temperture":temperture,
                          "Latitude":latitude,
                          "Longitude":longitude,
                          "City":city_found})
Weather_df
# Out:
#       Wind  Clouds  Humidity Country        Data  Temperture  Latitude  \
# 0    14.74       1        86      NC  1603339050       73.76    -22.67
# 1     5.99      96        54      NZ  1603339051       61.00    -46.60
# 2     8.05      75        61      CL  1603339051       48.20    -53.15
# 3     8.05       2        64      ES  1603339051       68.00     28.66
# 4     8.90     100        72      ID  1603339051       81.18     -3.80
# ..     ...     ...       ...     ...         ...         ...       ...
# 529  11.18      75        64      CN  1603339138       75.20     23.19
# 530   7.47      87        52      AU  1603339138       78.22    -25.53
# 531   2.71      20        87      US  1603339139       69.80     37.46
# 532   9.71      38        83      PE  1603339139       62.87    -11.10
# 533   1.99     100       100      RU  1603339139       36.00     53.82
#
#      Longitude                   City
# 0       167.48                    vao
# 1       168.33                  bluff
# 2       -70.92           punta arenas
# 3       -17.92  los llanos de aridane
# 4       102.27               bengkulu
# ..         ...                    ...
# 529     116.61                 haimen
# 530     152.70            maryborough
# 531    -122.43          half moon bay
# 532     -77.61                hualmay
# 533      39.55                 skopin
#
# [534 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_df.to_csv(output_cities)

# %%
Weather_df.describe()
# Out:
#              Wind      Clouds    Humidity          Data  Temperture  \
# count  534.000000  534.000000  534.000000  5.340000e+02  534.000000
# mean     7.616255   52.402622   74.359551  1.603339e+09   59.513090
# std      5.297678   38.741323   20.185768  6.757407e+01   20.807313
# min      0.220000    0.000000   11.000000  1.603339e+09   -0.400000
# 25%      3.475000   13.000000   64.000000  1.603339e+09   43.145000
# 50%      6.585000   58.500000   79.000000  1.603339e+09   64.000000
# 75%     10.290000   90.000000   90.750000  1.603339e+09   76.560000
# max     34.050000  100.000000  100.000000  1.603339e+09   98.600000
#
#         Latitude   Longitude
# count  534.00000  534.000000
# mean    21.09485   20.327547
# std     33.19678   92.704502
# min    -54.80000 -179.170000
# 25%     -6.18750  -61.505000
# 50%     25.68500   26.290000
# 75%     49.30500  108.160000
# max     78.22000  179.320000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_df = Weather_df.loc[Weather_df["Humidity"]>100]

humidity_df
# Out:
# Empty DataFrame
# Columns: [Wind, Clouds, Humidity, Country, Data, Temperture, Latitude, Longitude, City]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

#No cities have humidity greater than 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".


#No cities have humidity outliers

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
Latitude = Weather_df["Latitude"]
Temp = Weather_df["Temperture"]

plt.scatter(Latitude, Temp, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Max Temperature 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.show()
plt.savefig('Lat_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
Latitude = Weather_df["Latitude"]
Humidity= Weather_df["Humidity"]

plt.scatter(Latitude, Humidity, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Humidity 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.show()
plt.savefig('Lat_hum.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
Latitude = Weather_df["Latitude"]
Cloudiness= Weather_df["Clouds"]

plt.scatter(Latitude, Cloudiness, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Cloudiness 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.show()
plt.savefig('Lat_cloud.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
Latitude = Weather_df["Latitude"]
wind_speed= Weather_df["Wind"]

plt.scatter(Latitude, wind_speed, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Wind Speed (mph) 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.show()
plt.savefig('Lat_Ws.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#create northern hemisphre loc statement lat >0 northern df

nh_latitude = Weather_df[(Weather_df.Latitude >=0)]

North_lat = nh_latitude.iloc[:,6]
North_temp = nh_latitude.iloc[:,5]
correlation = st.pearsonr(North_lat,North_temp)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(North_lat, North_temp)
l_fit = l_slope * North_lat + l_int

plt.scatter(North_lat, North_temp, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Max Temperature in Northen Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.plot(North_lat,l_fit,"--")
plt.savefig('NhLat_temp.png')

print(f"The correlation coefficient between Latitude and Max temperture in the Northern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Max temperture in the Northern Hempisphere is -0.9

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#create southern hemisphre loc statement lat <0 southern df

sh_latitude = Weather_df[(Weather_df.Latitude <=0)]

sh_latitude

south_lat = sh_latitude.iloc[:,6]
south_temp = sh_latitude.iloc[:,5]
correlation = st.pearsonr(south_lat,south_temp)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(south_lat, south_temp)
l_fit = l_slope * south_lat + l_int

plt.scatter(south_lat, south_temp, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Max Temperature in Southern Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.plot(south_lat,l_fit,"--")
plt.savefig('ShLat_temp.png')
print(f"The correlation coefficient between Latitude and Max temperture in the Southern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Max temperture in the Southern Hempisphere is 0.65

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
nh_latitude = Weather_df[(Weather_df.Latitude >=0)]

North_lat = nh_latitude.iloc[:,6]
North_humidity = nh_latitude.iloc[:,2]
correlation = st.pearsonr(North_lat,North_humidity)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(North_lat, North_humidity)
l_fit = l_slope * North_lat + l_int

plt.scatter(North_lat, North_humidity, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Humidity % in Northen Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.plot(North_lat,l_fit,"--")
plt.savefig('NhLat_hum.png')

print(f"The correlation coefficient between Latitude and humidity % in the Northern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and humidity % in the Northern Hempisphere is 0.3

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
sh_latitude = Weather_df[(Weather_df.Latitude <=0)]

south_lat = sh_latitude.iloc[:,6]
south_humidity = sh_latitude.iloc[:,2]
correlation = st.pearsonr(south_lat,south_humidity)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(south_lat, south_humidity)
l_fit = l_slope * south_lat + l_int

plt.scatter(south_lat, south_humidity, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Humidity % in Southern Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.plot(south_lat,l_fit,"--")
plt.savefig('ShLat_hum.png')

print(f"The correlation coefficient between Latitude and humidity % in the Southern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and humidity % in the Southern Hempisphere is 0.16

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
nh_latitude = Weather_df[(Weather_df.Latitude >=0)]

North_lat = nh_latitude.iloc[:,6]
North_cloud = nh_latitude.iloc[:,1]
correlation = st.pearsonr(North_lat,North_cloud)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(North_lat, North_cloud)
l_fit = l_slope * North_lat + l_int

plt.scatter(North_lat, North_cloud, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Cloudiness in Northen Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.plot(North_lat,l_fit,"--")
plt.savefig('NhLat_cloud.png')

print(f"The correlation coefficient between Latitude and Cloudiness in the Northern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Cloudiness in the Northern Hempisphere is 0.25

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
sh_latitude = Weather_df[(Weather_df.Latitude <=0)]

south_lat = sh_latitude.iloc[:,6]
south_cloud = sh_latitude.iloc[:,1]
correlation = st.pearsonr(south_lat,south_cloud)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(south_lat, south_cloud)
l_fit = l_slope * south_lat + l_int

plt.scatter(south_lat, south_cloud, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Cloudiness in Southern Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.plot(south_lat,l_fit,"--")
plt.savefig('ShLat_Cloud.png')

print(f"The correlation coefficient between Latitude and Cloudiness in the Southern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Cloudiness in the Southern Hempisphere is 0.07

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
nh_latitude = Weather_df[(Weather_df.Latitude >=0)]

North_lat = nh_latitude.iloc[:,6]
North_ws = nh_latitude.iloc[:,0]
correlation = st.pearsonr(North_lat,North_ws)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(North_lat, North_ws)
l_fit = l_slope * North_lat + l_int

plt.scatter(North_lat, North_ws, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Wind Speed in Northen Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.plot(North_lat,l_fit,"--")
plt.savefig('NhLat_WS.png')

print(f"The correlation coefficient between Latitude and Wind Speed (mph) in the Northern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Wind Speed (mph) in the Northern Hempisphere is 0.14

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
sh_latitude = Weather_df[(Weather_df.Latitude <=0)]

south_lat = sh_latitude.iloc[:,6]
south_ws = sh_latitude.iloc[:,0]
correlation = st.pearsonr(south_lat,south_ws)
l_slope, l_int, l_r, l_p, l_std_err = stats.linregress(south_lat, south_ws)
l_fit = l_slope * south_lat + l_int

plt.scatter(south_lat, south_ws, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude vs Wind Speed in Southern Hempisphere 10/19/20")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.plot(south_lat,l_fit,"--")
plt.savefig('ShLat_Ws.png')

print(f"The correlation coefficient between Latitude and Wind Speed (mph) in the Southern Hempisphere is {round(correlation[0],2)}")
# Out:
# The correlation coefficient between Latitude and Wind Speed (mph) in the Southern Hempisphere is -0.19
